# %%
import data_prep as dp
import data_update as du
from genius_client import GeniusClient
import json
import pandas as pd

client = GeniusClient("1pe-P9UUnlnmzjOgBlw8ijD5oo_v2L1tkBjdDPM-UfPJhXDhlUzuXcSGhJU2DLYH")

# %%
dp.prep_song_data(client, 12095694)
# Out:
# <class 'pandas.core.series.Series'>
# 0    [{'label': 'Publisher', 'artists': [{'api_path...
# Name: custom_performances, dtype: object
#     song_id                        title  \
# 0  12095694  Gabriela (Extended Version)
#
#                                          description  primary_artist_id  \
# 0  “Gabriela (Extended Version)” is a Latin-inspi...            3740381
#
#   primary_artist_names language recording_location release_date    hot  \
# 0              KATSEYE       en               None   2025-07-03  False
#
#    pageviews song_art_primary_color song_art_secondary_color  album_id  \
# 0       9190                #e1d226                  #dec894   1475010
#
#                     album_title  \
# 0  BEAUTIFUL CHAOS: The Remixes
#
#                                  album_cover_art_url
# 0  https://images.genius.com/97eb7faa538a4f4201e7...

# %%
test = du.update_artist_data()
# Out:
# Index(['artist_id', 'name', 'description', 'alternate_names',
#        'header_image_url', 'image_url', 'social_links', 'followers_count'],
#       dtype='object')

# %%
df = pd.read_csv("data/artist_data.csv", sep=";")
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   artist_id;name;description;alternate_names;header_image_url;image_url;social_links;followers_count
# ...
